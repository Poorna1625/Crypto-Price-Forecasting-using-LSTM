# %%
# Libraries for data manipulation
import pandas as pd
import numpy as np
import math

# Libraries for visualization, including Matplotlib and Seaborn
import seaborn as sns
import matplotlib.pyplot as plt
import pandas.plotting as pd_plotting

# Libraries for data preprocessing
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split

# Libraries for building and training neural networks
from keras.models import Sequential
from keras.layers import LSTM, Dropout, Dense

# Libraries for model evaluation
from sklearn.metrics import mean_squared_error, r2_score

# Library for saving and loading machine learning models
import joblib

# %%
# 1. Load the Data
lit_data = pd.read_csv('LIT_historical_data.csv')
print(lit_data.tail())
# Out:
#                            Date       Open       High        Low      Close  \
# 1310  2023-08-03 00:00:00+00:00  87.491722  88.226562  82.696236  82.707794
# 1311  2023-08-04 00:00:00+00:00  82.693336  83.706123  81.506645  82.078911
# 1312  2023-08-05 00:00:00+00:00  82.086472  83.297775  81.581238  83.105591
# 1313  2023-08-06 00:00:00+00:00  83.100288  83.368553  82.089241  82.471703
# 1314  2023-08-07 00:00:00+00:00  82.470978  83.219833  80.512093  82.344521
#
#          Volume  Dividends  Stock Splits
# 1310  661629539        0.0           0.0
# 1311  574898134        0.0           0.0
# 1312  266995799        0.0           0.0
# 1313  261949686        0.0           0.0
# 1314  369980930        0.0           0.0

# %%
# Checking the shape of the data
lit_data.shape
# Out:
# (1315, 8)

# %%
# Describing the data to get statistical summary
lit_data.describe()
# Out:
#               Open         High          Low        Close        Volume  \
# count  1315.000000  1315.000000  1315.000000  1315.000000  1.315000e+03
# mean    104.354456   108.172417   100.245577   104.361825  2.533536e+09
# std      60.650218    64.019069    56.908748    60.586666  2.678568e+09
# min      31.004513    34.139050    25.573105    30.930883  1.783969e+08
# 25%      56.822599    58.699387    55.055815    56.977789  6.277725e+08
# 50%      87.576599    89.602104    85.433022    87.574631  1.645919e+09
# 75%     138.723236   144.284576   133.526558   138.638245  3.368097e+09
# max     387.869171   412.960144   345.298828   386.450775  1.799426e+10
#
#        Dividends  Stock Splits
# count     1315.0        1315.0
# mean         0.0           0.0
# std          0.0           0.0
# min          0.0           0.0
# 25%          0.0           0.0
# 50%          0.0           0.0
# 75%          0.0           0.0
# max          0.0           0.0

# %%
# Getting the info of the data
lit_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1315 entries, 0 to 1314
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Date          1315 non-null   object
#  1   Open          1315 non-null   float64
#  2   High          1315 non-null   float64
#  3   Low           1315 non-null   float64
#  4   Close         1315 non-null   float64
#  5   Volume        1315 non-null   int64
#  6   Dividends     1315 non-null   float64
#  7   Stock Splits  1315 non-null   float64
# dtypes: float64(6), int64(1), object(1)
# memory usage: 82.3+ KB

# %%
# Convert the "Date" column to a datetime format
lit_data['Date'] = pd.to_datetime(lit_data['Date'])

# Remove the time zone information (if any)
lit_data['Date'] = lit_data['Date'].dt.tz_localize(None)

# Checking the data types to confirm the conversion
lit_data.dtypes
# Out:
# Date            datetime64[ns]
# Open                   float64
# High                   float64
# Low                    float64
# Close                  float64
# Volume                   int64
# Dividends              float64
# Stock Splits           float64
# dtype: object

# %%
# Checking for missing values in the dataset
missing_values = lit_data.isnull().sum()
missing_values
# Out:
# Date            0
# Open            0
# High            0
# Low             0
# Close           0
# Volume          0
# Dividends       0
# Stock Splits    0
# dtype: int64

# %%
# Removing the "Dividends" and "Stock Splits" columns
lit_data_cleaned = lit_data.drop(columns=['Dividends', 'Stock Splits'])

# Checking the shape of the data after dropping 
lit_data_cleaned.shape
# Out:
# (1315, 6)

# %%
# Displaying the first few rows of the cleaned dataset
lit_data_cleaned.head()
# Out:
#         Date       Open       High        Low      Close      Volume
# 0 2020-01-01  41.326534  42.285019  41.288033  42.017719  2782992323
# 1 2020-01-02  42.018085  42.134747  39.683567  39.823013  2759827139
# 2 2020-01-03  39.863129  42.447174  39.450844  42.415573  3260961326
# 3 2020-01-04  42.383526  43.342705  41.933075  43.326607  2843192897
# 4 2020-01-05  43.291382  44.733616  42.998535  43.553207  3017148033

# %% [markdown]
# Lag Plot:-This plot helps you identify any autocorrelation in the time series data the points cluster along a diagonal line from the bottom-left to the top-right of the plot, it suggests a positive linear relationship

# %%
# Drawing the lag plot for the closing price with a daily lag (1-row shift)
pd_plotting.lag_plot(lit_data_cleaned['Close'], lag=1)
plt.title('Lag Plot of Closing Price (Daily Lag, 1-row shift)')
plt.show()

# %% [markdown]
# Time Series Plot: plotted the closing price against the date, which is an essential visualization to understand the trend, seasonality, and any anomalies in the data

# %%
# Plotting the Lite coin closing price trend over time
plt.figure(figsize=(14,6))
plt.plot(lit_data_cleaned['Date'], lit_data_cleaned['Close'])
plt.title('Litecoin Closing Price Trend')
plt.xlabel('Date')
plt.ylabel('Close Price')
plt.show()

# %%
# Plotting the 'Open', 'High', 'Low', and 'Close' features on the same graph 

plt.figure(figsize=(14,6))
for feature in ['Open', 'High', 'Low', 'Close']:
    plt.plot(lit_data_cleaned['Date'], lit_data_cleaned[feature], label=feature)

plt.title('Litecoin Price Trends (2020 Onward)')
plt.xlabel('Date')
plt.ylabel('Price')
plt.legend()
plt.show()

# %%
# Resampling the data by month and calculating the mean for the 'Open' and 'Close' prices
monthly_average_data = lit_data_cleaned.resample('M', on='Date')[['Open', 'Close']].mean()

# Plotting the monthly average 'Open' and 'Close' prices in a bar chart
monthly_average_data.plot(kind='bar', figsize=(14,6))
plt.title('Monthly Average Open and Close Prices')
plt.xlabel('Date')
plt.ylabel('Price')
plt.show()

# %% [markdown]
# Boxplot: The boxplot helps you understand the distribution of the closing prices, including the median, quartiles, and potential outliers

# %%
# Plotting a boxplot of Litecoin's closing prices to visualize distribution and outliers
plt.figure(figsize=(8,6))
sns.boxplot(lit_data_cleaned['Close'])
plt.title('Boxplot of Closing Prices')
plt.xlabel('Close Price')
plt.show()

# %%
# Plotting a histogram of Litecoin's closing prices to understand the frequency distribution
plt.figure(figsize=(8,6))
plt.hist(lit_data_cleaned['Close'], bins=40)
plt.title('Histogram of Closing Prices')
plt.xlabel('Close Price')
plt.ylabel('Frequency')
plt.show()

# %%
# Creating a correlation heatmap to visualize the relationships between 'Open', 'High', 'Low', and 'Close' attributes
correlation_matrix = lit_data_cleaned[['Open', 'High', 'Low', 'Close']].corr()
plt.figure(figsize=(8,6))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm')
plt.title('Correlation Heatmap')
plt.show()

# %%
from statsmodels.tsa.seasonal import seasonal_decompose

# Setting the Date as the index, performing seasonal decomposition on the 'Close' attribute, and plotting the components

# Set the Date as the index
lit_data_cleaned.set_index('Date', inplace=True)

# Perform seasonal decomposition
decomposition = seasonal_decompose(lit_data_cleaned['Close'], period=30) # we can change the period

# Plot the components
decomposition.plot()
plt.show()

# %%
# Grouping the data by 'Date'
group = lit_data_cleaned.groupby('Date')

# Calculating the mean of the 'Close' column for each date
lit_closing_price_groupby_date = group['Close'].mean()

# Displaying the first 10 rows of the grouped data
display(lit_closing_price_groupby_date.head(10))

# Printing the length of the grouped data
print("Length of lit_closing_price_groupby_date :", len(lit_closing_price_groupby_date))
# Out:
# Date
# 2020-01-01    42.017719
# 2020-01-02    39.823013
# 2020-01-03    42.415573
# 2020-01-04    43.326607
# 2020-01-05    43.553207
# 2020-01-06    45.816353
# 2020-01-07    46.424583
# 2020-01-08    45.653767
# 2020-01-09    45.215931
# 2020-01-10    48.727329
# Name: Close, dtype: float64
# Length of lit_closing_price_groupby_date : 1315

# %%
# Setting the prediction days
prediction_days = 500

# Set Train data to be up to (Total data length - prediction_days)
df_train = lit_closing_price_groupby_date[:len(lit_closing_price_groupby_date) - prediction_days].values.reshape(-1, 1)

# Set Test data to be the last prediction_days (or 60 days in this case)
df_test = lit_closing_price_groupby_date[len(lit_closing_price_groupby_date) - prediction_days:].values.reshape(-1, 1)

df_train.shape, df_test.shape
# Out:
# ((815, 1), (500, 1))

# %%
# Create a figure and set the size of the plot
plt.figure(figsize=(15, 6))

# Plot the training data (all data except the last 60 days) using the 'Close' price
# The blue line represents the training data, which includes the historical closing prices up to 60 days before the end of the dataset
plt.plot(lit_closing_price_groupby_date.index[:len(lit_closing_price_groupby_date) - prediction_days], df_train, label='Training Data')

# Plot the test data (the last 60 days) using the 'Close' price
# The red line represents the test data, which includes the closing prices for the last 60 days of the dataset
plt.plot(lit_closing_price_groupby_date.index[len(lit_closing_price_groupby_date) - prediction_days:], df_test, label='Test Data', color='red')

# Add a title to the plot, describing the content
plt.title('Training and Test Split of LITE Closing Prices')

# Label the x-axis as 'Date'
plt.xlabel('Date')

# Label the y-axis as 'Close Price'
plt.ylabel('Close Price')

# Add a legend to the plot to differentiate between the training and test data
plt.legend()

# Display the plot
plt.show()

# %%
# Scaling the training data using MinMaxScaler
scaler = MinMaxScaler(feature_range=(0, 1))
scaled_train = scaler.fit_transform(df_train)

# Scaling the test data using the same scaler fit on the training data
scaled_test = scaler.transform(df_test)

# Shapes of the scaled training and test data
scaled_train.shape, scaled_test.shape
# Out:
# ((815, 1), (500, 1))

# %%
# Defining the look_back value
# This value determines how many previous timesteps are used to predict the next value in the sequence
look_back = 10

# Function to generate input-output pairs for an LSTM dataset
def dataset_generator_lstm(dataset, look_back=look_back):
    dataX, dataY = [], []
    for i in range(len(dataset) - look_back):
        # Extracting the window of 'look_back' previous timesteps for input
        window_size_x = dataset[i:(i + look_back), 0]
        dataX.append(window_size_x)
        # Extracting the next timestep value as the corresponding output
        dataY.append(dataset[i + look_back, 0])
    return np.array(dataX), np.array(dataY)

# Generating the sequences for training data using scaled_train (scaled closing prices for training)
trainX, trainY = dataset_generator_lstm(scaled_train)

# Generating the sequences for test data using scaled_test (scaled closing prices for testing)
testX, testY = dataset_generator_lstm(scaled_test)

# Printing the shapes of the generated sequences
# These shapes represent the number of sequences and the length of each sequence for both training and test data
print("Shape of trainX:", trainX.shape)
print("Shape of trainY:", trainY.shape)
print("Shape of testX:", testX.shape)
print("Shape of testY:", testY.shape)
# Out:
# Shape of trainX: (805, 10)
# Shape of trainY: (805,)
# Shape of testX: (490, 10)
# Shape of testY: (490,)

# %%
# Printing the first 5 sequences for training and test input and output data

print("First 5 sequences of trainX:\n", trainX[:5])
print("\nFirst 5 corresponding values of trainY:\n", trainY[:5])
print("\nFirst 5 sequences of testX:\n", testX[:5])
print("\nFirst 5 corresponding values of testY:\n", testY[:5])
# Out:
# First 5 sequences of trainX:
#  [[0.03118485 0.02501162 0.03230393 0.03486647 0.03550385 0.04186958
#   0.0435804  0.04141226 0.04018073 0.05005752]
#  [0.02501162 0.03230393 0.03486647 0.03550385 0.04186958 0.0435804
#   0.04141226 0.04018073 0.05005752 0.05156641]
#  [0.03230393 0.03486647 0.03550385 0.04186958 0.0435804  0.04141226
#   0.04018073 0.05005752 0.05156641 0.05667715]
#  [0.03486647 0.03550385 0.04186958 0.0435804  0.04141226 0.04018073
#   0.05005752 0.05156641 0.05667715 0.05288842]
#  [0.03550385 0.04186958 0.0435804  0.04141226 0.04018073 0.05005752
#   0.05156641 0.05667715 0.05288842 0.07748469]]
#
# First 5 corresponding values of trainY:
#  [0.05156641 0.05667715 0.05288842 0.07748469 0.07628818]
#
# First 5 sequences of testX:
#  [[0.26426214 0.27696507 0.27286161 0.27883208 0.28194895 0.26098435
#   0.26426734 0.26438071 0.27569577 0.26420693]
#  [0.27696507 0.27286161 0.27883208 0.28194895 0.26098435 0.26426734
#   0.26438071 0.27569577 0.26420693 0.25956998]
#  [0.27286161 0.27883208 0.28194895 0.26098435 0.26426734 0.26438071
#   0.27569577 0.26420693 0.25956998 0.2293274 ]
#  [0.27883208 0.28194895 0.26098435 0.26426734 0.26438071 0.27569577
#   0.26420693 0.25956998 0.2293274  0.23430281]
#  [0.28194895 0.26098435 0.26426734 0.26438071 0.27569577 0.26420693
#   0.25956998 0.2293274  0.23430281 0.22488525]]
#
# First 5 corresponding values of testY:
#  [0.25956998 0.2293274  0.23430281 0.22488525 0.23021607]

# %%
# Reshaping the input data to be a 3D tensor (samples, time steps, features)
# LSTM models require input data in this shape, where 'samples' is the number of input sequences,
# 'time steps' is the length of each sequence (in this case, defined by 'look_back'), and 'features' is the number of features at each timestep (1 in this case)

# Reshaping the training input data (trainX) to have the required 3D shape
trainX_reshaped = trainX.reshape(trainX.shape[0], look_back, 1)

# Reshaping the test input data (testX) to have the required 3D shape
testX_reshaped = testX.reshape(testX.shape[0], look_back, 1)

# Printing the shapes of the reshaped data
# These shapes confirm that the data is now in the required 3D format, suitable for training an LSTM model
print("Shape of trainX_reshaped:", trainX_reshaped.shape)
print("Shape of testX_reshaped:", testX_reshaped.shape)
# Out:
# Shape of trainX_reshaped: (805, 10, 1)
# Shape of testX_reshaped: (490, 10, 1)

# %%
# Printing the first 5 sequences of both the reshaped training and testing data
print("First 5 sequences of trainX_reshaped:\n", trainX_reshaped[:5])
print(" ********** ")
print("First 5 sequences of testX_reshaped:\n", testX_reshaped[:5])
# Out:
# First 5 sequences of trainX_reshaped:
#  [[[0.03118485]
#   [0.02501162]
#   [0.03230393]
#   [0.03486647]
#   [0.03550385]
#   [0.04186958]
#   [0.0435804 ]
#   [0.04141226]
#   [0.04018073]
#   [0.05005752]]
#
#  [[0.02501162]
#   [0.03230393]
#   [0.03486647]
#   [0.03550385]
#   [0.04186958]
#   [0.0435804 ]
#   [0.04141226]
#   [0.04018073]
#   [0.05005752]
#   [0.05156641]]
#
#  [[0.03230393]
#   [0.03486647]
#   [0.03550385]
#   [0.04186958]
#   [0.0435804 ]
#   [0.04141226]
#   [0.04018073]
#   [0.05005752]
#   [0.05156641]
#   [0.05667715]]
#
#  [[0.03486647]
#   [0.03550385]
#   [0.04186958]
#   [0.0435804 ]
#   [0.04141226]
#   [0.04018073]
#   [0.05005752]
#   [0.05156641]
#   [0.05667715]
#   [0.05288842]]
#
#  [[0.03550385]
#   [0.04186958]
#   [0.0435804 ]
#   [0.04141226]
#   [0.04018073]
#   [0.05005752]
#   [0.05156641]
#   [0.05667715]
#   [0.05288842]
#   [0.07748469]]]
#  **********
# First 5 sequences of testX_reshaped:
#  [[[0.26426214]
#   [0.27696507]
#   [0.27286161]
#   [0.27883208]
#   [0.28194895]
#   [0.26098435]
#   [0.26426734]
#   [0.26438071]
#   [0.27569577]
#   [0.26420693]]
#
#  [[0.27696507]
#   [0.27286161]
#   [0.27883208]
#   [0.28194895]
#   [0.26098435]
#   [0.26426734]
#   [0.26438071]
#   [0.27569577]
#   [0.26420693]
#   [0.25956998]]
#
#  [[0.27286161]
#   [0.27883208]
#   [0.28194895]
#   [0.26098435]
#   [0.26426734]
#   [0.26438071]
#   [0.27569577]
#   [0.26420693]
#   [0.25956998]
#   [0.2293274 ]]
#
#  [[0.27883208]
#   [0.28194895]
#   [0.26098435]
#   [0.26426734]
#   [0.26438071]
#   [0.27569577]
#   [0.26420693]
#   [0.25956998]
#   [0.2293274 ]
#   [0.23430281]]
#
#  [[0.28194895]
#   [0.26098435]
#   [0.26426734]
#   [0.26438071]
#   [0.27569577]
#   [0.26420693]
#   [0.25956998]
#   [0.2293274 ]
#   [0.23430281]
#   [0.22488525]]]

# %%
# Checking the values for input_shape (timesteps, n_features) using the reshaped data
timesteps = trainX_reshaped.shape[1]
n_features = trainX_reshaped.shape[2]

print("timesteps in input_shape = (timesteps, n_features):", timesteps)
print("n_features in input_shape = (timesteps, n_features):", n_features)
# Out:
# timesteps in input_shape = (timesteps, n_features): 10
# n_features in input_shape = (timesteps, n_features): 1

# %%
from tensorflow.keras.optimizers import Adam

def create_model(units, dropout_rate, lookback_period, learning_rate):
    model = Sequential()
    # First LSTM layer with specified units and return_sequences=True for stacking
    model.add(LSTM(units=units, activation='relu', return_sequences=True, input_shape=(lookback_period, 1)))
    # Dropout layer to prevent overfitting
    model.add(Dropout(dropout_rate))
    # Second LSTM layer with half the units
    model.add(LSTM(units=units//2))
    # Dropout layer to prevent overfitting
    model.add(Dropout(dropout_rate))
    # Output Dense layer with 1 unit for regression
    model.add(Dense(units=1))
    # Compiling the model with the Adam optimizer and mean squared error loss function
    model.compile(optimizer=Adam(learning_rate=learning_rate), loss='mean_squared_error') # Set custom learning rate
    return model

# Parameters for the model
units = 64          # Adjusted number of LSTM units
dropout_rate = 0.3
lookback_period = look_back
learning_rate = 0.001  # Adjusted learning rate


# Creating the model
model = create_model(units, dropout_rate, lookback_period, learning_rate)
# Displaying the model summary
model.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_8 (LSTM)               (None, 10, 64)            16896
#
#  dropout_8 (Dropout)         (None, 10, 64)            0
#
#  lstm_9 (LSTM)               (None, 32)                12416
#
#  dropout_9 (Dropout)         (None, 32)                0
#
#  dense_4 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 29,345
# Trainable params: 29,345
# Non-trainable params: 0
# _________________________________________________________________

# %%
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping

# Define the checkpoint path to save the best model
checkpoint_path = 'my_best_model.hdf5'

# Create a checkpoint callback to save the model with the lowest validation loss
checkpoint = ModelCheckpoint(filepath=checkpoint_path, 
                             monitor='val_loss',
                             verbose=1, 
                             save_best_only=True,
                             mode='min')

# Create an early stopping callback to stop training if validation loss doesn't improve for 20 epochs
earlystopping = EarlyStopping(monitor='val_loss', patience=30, restore_best_weights=True)

# List of callbacks
callbacks = [checkpoint, earlystopping]

# Fit the model with training data, validation data, and callbacks
# Using the reshaped training and test data for training and validation
history = model.fit(trainX_reshaped, trainY, batch_size=32, epochs=300, verbose=1, shuffle=False, validation_data=(testX_reshaped, testY), callbacks=callbacks)
# Out:
# Epoch 1/300
# 23/26 [=========================>....] - ETA: 0s - loss: 0.0401
# Epoch 1: val_loss improved from inf to 0.04070, saving model to my_best_model.hdf5
# 26/26 [==============================] - 4s 52ms/step - loss: 0.0376 - val_loss: 0.0407
# Epoch 2/300
# 24/26 [==========================>...] - ETA: 0s - loss: 0.0335
# Epoch 2: val_loss improved from 0.04070 to 0.00925, saving model to my_best_model.hdf5
# 26/26 [==============================] - 0s 17ms/step - loss: 0.0322 - val_loss: 0.0092
# Epoch 3/300
# 23/26 [=========================>....] - ETA: 0s - loss: 0.0104
# Epoch 3: val_loss improved from 0.00925 to 0.00031, saving model to my_best_model.hdf5
# 26/26 [==============================] - 0s 17ms/step - loss: 0.0098 - val_loss: 3.0636e-04
# Epoch 4/300
# 22/26 [========================>.....] - ETA: 0s - loss: 0.0054
# Epoch 4: val_loss improved from 0.00031 to 0.00029, saving model to my_best_model.hdf5
# 26/26 [==============================] - 0s 15ms/step - loss: 0.0050 - val_loss: 2.8869e-04
# Epoch 5/300
# 24/26 [==========================>...] - ETA: 0s - loss: 0.0050
# Epoch 5: val_loss did not improve from 0.00029
# 26/26 [==============================] - 0s 13ms/step - loss: 0.0049 - val_loss: 3.9183e-04
# Epoch 6/300
# 24/26 [==========================>...] - ETA: 0s - loss: 0.0052
# Epoch 6: val_loss did not improve from 0.00029
# 26/26 [==============================] - 0s 13ms/step - loss: 0.0051 - val_loss: 4.0089e-04
# Epoch 7/300
# 22/26 [========================>.....] - ETA: 0s - loss: 0.0060
# Epoch 7: val_loss did not improve from 0.00029
# 26/26 [==============================] - 0s 14ms/step - loss: 0.0058 - val_loss: 7.4740e-04
# Epoch 8/300
# 22/26 [========================>.....] - ETA: 0s - loss: 0.0080
# Epoch 8: val_loss did not improve from 0.00029
# 26/26 [==============================] - 0s 13ms/step - loss: 0.0077 - val_loss: 9.9693e-04
# Epoch 9/300
# 24/26 [==========================>...] - ETA: 0s - loss: 0.0076
# Epoch 9: val_loss did not improve from 0.00029
# 26/26 [==============================] - 0s 13ms/step - loss: 0.0074 - val_loss: 0.0022
# Epoch 10/300
# 26/26 [==============================] - ETA: 0s - loss: 0.0057
# Epoch 10: val_loss did not improve from 0.00029
# 26/26 [==============================] - 0s 15ms/step - loss: 0.0057 - val_loss: 4.4401e-04
# Epoch 11/300
# 22/26 [========================>.....] - ETA: 0s - loss: 0.0052
# Epoch 11: val_loss did not improve from 0.00029
# 26/26 [==============================] - 0s 14ms/step - loss: 0.0049 - val_loss: 4.0215e-04
# Epoch 12/300
# 24/26 [==========================>...] - ETA: 0s - loss: 0.0049
# Epoch 12: val_loss did not improve from 0.00029
# 26/26 [==============================] - 0s 13ms/step - loss: 0.0048 - val_loss: 2.9288e-04
# Epoch 13/300
# 23/26 [=========================>....] - ETA: 0s - loss: 0.0050
# Epoch 13: val_loss did not improve from 0.00029
# 26/26 [==============================] - 0s 13ms/step - loss: 0.0048 - val_loss: 7.2813e-04
# Epoch 14/300
# 24/26 [==========================>...] - ETA: 0s - loss: 0.0057
# Epoch 14: val_loss did not improve from 0.00029
# 26/26 [==============================] - 0s 13ms/step - loss: 0.0056 - val_loss: 4.3081e-04
# Epoch 15/300
# 21/26 [=======================>......] - ETA: 0s - loss: 0.0073
# Epoch 15: val_loss did not improve from 0.00029
# 26/26 [==============================] - 0s 14ms/step - loss: 0.0074 - val_loss: 0.0024
# Epoch 16/300
# 26/26 [==============================] - ETA: 0s - loss: 0.0077
# Epoch 16: val_loss did not improve from 0.00029
# 26/26 [==============================] - 0s 14ms/step - loss: 0.0077 - val_loss: 0.0011
# Epoch 17/300
# 22/26 [========================>.....] - ETA: 0s - loss: 0.0043
# Epoch 17: val_loss improved from 0.00029 to 0.00028, saving model to my_best_model.hdf5
# 26/26 [==============================] - 0s 18ms/step - loss: 0.0041 - val_loss: 2.7577e-04
# Epoch 18/300
# 23/26 [=========================>....] - ETA: 0s - loss: 0.0041
# Epoch 18: val_loss did not improve from 0.00028
# 26/26 [==============================] - 0s 14ms/step - loss: 0.0039 - val_loss: 4.3972e-04
# Epoch 19/300
# 24/26 [==========================>...] - ETA: 0s - loss: 0.0051
# Epoch 19: val_loss did not improve from 0.00028
# 26/26 [==============================] - 0s 13ms/step - loss: 0.0049 - val_loss: 3.0661e-04
# Epoch 20/300
# 23/26 [=========================>....] - ETA: 0s - loss: 0.0048
# Epoch 20: val_loss did not improve from 0.00028
# 26/26 [==============================] - 0s 14ms/step - loss: 0.0048 - val_loss: 0.0012
# Epoch 21/300
# 22/26 [========================>.....] - ETA: 0s - loss: 0.0055
# Epoch 21: val_loss did not improve from 0.00028
# 26/26 [==============================] - 0s 14ms/step - loss: 0.0053 - val_loss: 5.7538e-04
# Epoch 22/300
# 22/26 [========================>.....] - ETA: 0s - loss: 0.0045
# Epoch 22: val_loss did not improve from 0.00028
# 26/26 [==============================] - 0s 13ms/step - loss: 0.0043 - val_loss: 6.5605e-04
# Epoch 23/300
# 25/26 [===========================>..] - ETA: 0s - loss: 0.0041
# Epoch 23: val_loss did not improve from 0.00028
# 26/26 [==============================] - 0s 13ms/step - loss: 0.0041 - val_loss: 3.0422e-04
# Epoch 24/300
# 23/26 [=========================>....] - ETA: 0s - loss: 0.0051
# Epoch 24: val_loss did not improve from 0.00028
# 26/26 [==============================] - 0s 13ms/step - loss: 0.0049 - val_loss: 7.0966e-04
# Epoch 25/300
# 21/26 [=======================>......] - ETA: 0s - loss: 0.0052
# Epoch 25: val_loss did not improve from 0.00028
# 26/26 [==============================] - 0s 14ms/step - loss: 0.0054 - val_loss: 0.0010
# Epoch 26/300
# 24/26 [==========================>...] - ETA: 0s - loss: 0.0039
# Epoch 26: val_loss did not improve from 0.00028
# 26/26 [==============================] - 0s 13ms/step - loss: 0.0038 - val_loss: 3.3591e-04
# Epoch 27/300
# 24/26 [==========================>...] - ETA: 0s - loss: 0.0037
# Epoch 27: val_loss did not improve from 0.00028
# 26/26 [==============================] - 0s 13ms/step - loss: 0.0036 - val_loss: 4.8843e-04
# Epoch 28/300
# 24/26 [==========================>...] - ETA: 0s - loss: 0.0046
# Epoch 28: val_loss did not improve from 0.00028
# 26/26 [==============================] - 0s 13ms/step - loss: 0.0044 - val_loss: 3.5584e-04
# Epoch 29/300
# 24/26 [==========================>...] - ETA: 0s - loss: 0.0044
# Epoch 29: val_loss did not improve from 0.00028
# 26/26 [==============================] - 0s 13ms/step - loss: 0.0043 - val_loss: 9.2351e-04
# Epoch 30/300
# 24/26 [==========================>...] - ETA: 0s - loss: 0.0058
# Epoch 30: val_loss did not improve from 0.00028
# 26/26 [==============================] - 0s 13ms/step - loss: 0.0056 - val_loss: 9.1559e-04
# Epoch 31/300
# 24/26 [==========================>...] - ETA: 0s - loss: 0.0052
# Epoch 31: val_loss did not improve from 0.00028
# 26/26 [==============================] - 0s 13ms/step - loss: 0.0051 - val_loss: 4.4239e-04
# Epoch 32/300
# 24/26 [==========================>...] - ETA: 0s - loss: 0.0040
# Epoch 32: val_loss did not improve from 0.00028
# 26/26 [==============================] - 0s 13ms/step - loss: 0.0038 - val_loss: 5.8344e-04
# Epoch 33/300
# 22/26 [========================>.....] - ETA: 0s - loss: 0.0050
# Epoch 33: val_loss did not improve from 0.00028
# 26/26 [==============================] - 0s 14ms/step - loss: 0.0047 - val_loss: 7.8071e-04
# Epoch 34/300
# 24/26 [==========================>...] - ETA: 0s - loss: 0.0042
# Epoch 34: val_loss did not improve from 0.00028
# 26/26 [==============================] - 0s 13ms/step - loss: 0.0041 - val_loss: 4.6499e-04
# Epoch 35/300
# 24/26 [==========================>...] - ETA: 0s - loss: 0.0037
# Epoch 35: val_loss did not improve from 0.00028
# 26/26 [==============================] - 0s 13ms/step - loss: 0.0036 - val_loss: 3.6805e-04
# Epoch 36/300
# 24/26 [==========================>...] - ETA: 0s - loss: 0.0040
# Epoch 36: val_loss did not improve from 0.00028
# 26/26 [==============================] - 0s 13ms/step - loss: 0.0039 - val_loss: 7.9117e-04
# Epoch 37/300
# 24/26 [==========================>...] - ETA: 0s - loss: 0.0038
# Epoch 37: val_loss improved from 0.00028 to 0.00025, saving model to my_best_model.hdf5
# 26/26 [==============================] - 0s 14ms/step - loss: 0.0037 - val_loss: 2.5401e-04
# Epoch 38/300
# 23/26 [=========================>....] - ETA: 0s - loss: 0.0036
# Epoch 38: val_loss did not improve from 0.00025
# 26/26 [==============================] - 0s 13ms/step - loss: 0.0034 - val_loss: 2.6205e-04
# Epoch 39/300
# 24/26 [==========================>...] - ETA: 0s - loss: 0.0048
# Epoch 39: val_loss did not improve from 0.00025
# 26/26 [==============================] - 0s 13ms/step - loss: 0.0047 - val_loss: 0.0014
# Epoch 40/300
# 26/26 [==============================] - ETA: 0s - loss: 0.0049
# Epoch 40: val_loss did not improve from 0.00025
# 26/26 [==============================] - 0s 15ms/step - loss: 0.0049 - val_loss: 2.7400e-04
# Epoch 41/300
# 24/26 [==========================>...] - ETA: 0s - loss: 0.0031
# Epoch 41: val_loss did not improve from 0.00025
# 26/26 [==============================] - 0s 13ms/step - loss: 0.0030 - val_loss: 7.5305e-04
# Epoch 42/300
# 22/26 [========================>.....] - ETA: 0s - loss: 0.0050
# Epoch 42: val_loss did not improve from 0.00025
# 26/26 [==============================] - 0s 14ms/step - loss: 0.0045 - val_loss: 8.6822e-04
# Epoch 43/300
# 24/26 [==========================>...] - ETA: 0s - loss: 0.0069
# Epoch 43: val_loss did not improve from 0.00025
# 26/26 [==============================] - 0s 13ms/step - loss: 0.0067 - val_loss: 6.6296e-04
# Epoch 44/300
# 24/26 [==========================>...] - ETA: 0s - loss: 0.0032
# Epoch 44: val_loss did not improve from 0.00025
# 26/26 [==============================] - 0s 13ms/step - loss: 0.0031 - val_loss: 6.4499e-04
# Epoch 45/300
# 24/26 [==========================>...] - ETA: 0s - loss: 0.0029
# Epoch 45: val_loss improved from 0.00025 to 0.00024, saving model to my_best_model.hdf5
# 26/26 [==============================] - 0s 14ms/step - loss: 0.0028 - val_loss: 2.4154e-04
# Epoch 46/300
# 24/26 [==========================>...] - ETA: 0s - loss: 0.0028
# Epoch 46: val_loss did not improve from 0.00024
# 26/26 [==============================] - 0s 13ms/step - loss: 0.0027 - val_loss: 3.4059e-04
# Epoch 47/300
# 23/26 [=========================>....] - ETA: 0s - loss: 0.0035
# Epoch 47: val_loss did not improve from 0.00024
# 26/26 [==============================] - 0s 14ms/step - loss: 0.0033 - val_loss: 2.7853e-04
# Epoch 48/300
# 24/26 [==========================>...] - ETA: 0s - loss: 0.0033
# Epoch 48: val_loss did not improve from 0.00024
# 26/26 [==============================] - 0s 13ms/step - loss: 0.0032 - val_loss: 6.0100e-04
# Epoch 49/300
# 24/26 [==========================>...] - ETA: 0s - loss: 0.0037
# Epoch 49: val_loss did not improve from 0.00024
# 26/26 [==============================] - 0s 13ms/step - loss: 0.0036 - val_loss: 4.1265e-04
# Epoch 50/300
# 24/26 [==========================>...] - ETA: 0s - loss: 0.0033
# Epoch 50: val_loss did not improve from 0.00024
# 26/26 [==============================] - 0s 13ms/step - loss: 0.0032 - val_loss: 6.4272e-04
# Epoch 51/300
# 24/26 [==========================>...] - ETA: 0s - loss: 0.0030
# Epoch 51: val_loss did not improve from 0.00024
# 26/26 [==============================] - 0s 13ms/step - loss: 0.0029 - val_loss: 3.0424e-04
# Epoch 52/300
# 24/26 [==========================>...] - ETA: 0s - loss: 0.0028
# Epoch 52: val_loss did not improve from 0.00024
# 26/26 [==============================] - 0s 13ms/step - loss: 0.0027 - val_loss: 2.6469e-04
# Epoch 53/300
# 22/26 [========================>.....] - ETA: 0s - loss: 0.0032
# Epoch 53: val_loss did not improve from 0.00024
# 26/26 [==============================] - 0s 14ms/step - loss: 0.0030 - val_loss: 4.5760e-04
# Epoch 54/300
# 24/26 [==========================>...] - ETA: 0s - loss: 0.0032
# Epoch 54: val_loss did not improve from 0.00024
# 26/26 [==============================] - 0s 13ms/step - loss: 0.0031 - val_loss: 4.1961e-04
# Epoch 55/300
# 26/26 [==============================] - ETA: 0s - loss: 0.0032
# Epoch 55: val_loss did not improve from 0.00024
# 26/26 [==============================] - 0s 14ms/step - loss: 0.0032 - val_loss: 3.8391e-04
# Epoch 56/300
# 24/26 [==========================>...] - ETA: 0s - loss: 0.0032
# Epoch 56: val_loss did not improve from 0.00024
# 26/26 [==============================] - 0s 13ms/step - loss: 0.0031 - val_loss: 4.2285e-04
# Epoch 57/300
# 24/26 [==========================>...] - ETA: 0s - loss: 0.0038
# Epoch 57: val_loss did not improve from 0.00024
# 26/26 [==============================] - 0s 13ms/step - loss: 0.0037 - val_loss: 5.6279e-04
# Epoch 58/300
# 24/26 [==========================>...] - ETA: 0s - loss: 0.0031
# Epoch 58: val_loss did not improve from 0.00024
# 26/26 [==============================] - 0s 13ms/step - loss: 0.0030 - val_loss: 4.5308e-04
# Epoch 59/300
# 24/26 [==========================>...] - ETA: 0s - loss: 0.0030
# Epoch 59: val_loss did not improve from 0.00024
# 26/26 [==============================] - 0s 13ms/step - loss: 0.0029 - val_loss: 3.4834e-04
# Epoch 60/300
# 23/26 [=========================>....] - ETA: 0s - loss: 0.0023
# Epoch 60: val_loss improved from 0.00024 to 0.00020, saving model to my_best_model.hdf5
# 26/26 [==============================] - 0s 15ms/step - loss: 0.0022 - val_loss: 2.0469e-04
# Epoch 61/300
# 21/26 [=======================>......] - ETA: 0s - loss: 0.0032
# Epoch 61: val_loss did not improve from 0.00020
# 26/26 [==============================] - 0s 14ms/step - loss: 0.0034 - val_loss: 3.8694e-04
# Epoch 62/300
# 25/26 [===========================>..] - ETA: 0s - loss: 0.0039
# Epoch 62: val_loss did not improve from 0.00020
# 26/26 [==============================] - 0s 15ms/step - loss: 0.0038 - val_loss: 6.3100e-04
# Epoch 63/300
# 22/26 [========================>.....] - ETA: 0s - loss: 0.0034
# Epoch 63: val_loss did not improve from 0.00020
# 26/26 [==============================] - 0s 14ms/step - loss: 0.0031 - val_loss: 4.4113e-04
# Epoch 64/300
# 23/26 [=========================>....] - ETA: 0s - loss: 0.0028
# Epoch 64: val_loss did not improve from 0.00020
# 26/26 [==============================] - 0s 13ms/step - loss: 0.0026 - val_loss: 4.9131e-04
# Epoch 65/300
# 23/26 [=========================>....] - ETA: 0s - loss: 0.0024
# Epoch 65: val_loss did not improve from 0.00020
# 26/26 [==============================] - 0s 14ms/step - loss: 0.0023 - val_loss: 2.2426e-04
# Epoch 66/300
# 26/26 [==============================] - ETA: 0s - loss: 0.0033
# Epoch 66: val_loss did not improve from 0.00020
# 26/26 [==============================] - 0s 14ms/step - loss: 0.0033 - val_loss: 3.3186e-04
# Epoch 67/300
# 24/26 [==========================>...] - ETA: 0s - loss: 0.0047
# Epoch 67: val_loss did not improve from 0.00020
# 26/26 [==============================] - 0s 13ms/step - loss: 0.0045 - val_loss: 6.6552e-04
# Epoch 68/300
# 25/26 [===========================>..] - ETA: 0s - loss: 0.0032
# Epoch 68: val_loss did not improve from 0.00020
# 26/26 [==============================] - 0s 15ms/step - loss: 0.0031 - val_loss: 2.7519e-04
# Epoch 69/300
# 24/26 [==========================>...] - ETA: 0s - loss: 0.0036
# Epoch 69: val_loss did not improve from 0.00020
# 26/26 [==============================] - 0s 13ms/step - loss: 0.0035 - val_loss: 0.0013
# Epoch 70/300
# 22/26 [========================>.....] - ETA: 0s - loss: 0.0034
# Epoch 70: val_loss did not improve from 0.00020
# 26/26 [==============================] - 0s 15ms/step - loss: 0.0031 - val_loss: 2.8126e-04
# Epoch 71/300
# 21/26 [=======================>......] - ETA: 0s - loss: 0.0028
# Epoch 71: val_loss did not improve from 0.00020
# 26/26 [==============================] - 0s 14ms/step - loss: 0.0026 - val_loss: 3.3358e-04
# Epoch 72/300
# 24/26 [==========================>...] - ETA: 0s - loss: 0.0027
# Epoch 72: val_loss did not improve from 0.00020
# 26/26 [==============================] - 0s 13ms/step - loss: 0.0026 - val_loss: 2.2839e-04
# Epoch 73/300
# 24/26 [==========================>...] - ETA: 0s - loss: 0.0033
# Epoch 73: val_loss did not improve from 0.00020
# 26/26 [==============================] - 0s 13ms/step - loss: 0.0032 - val_loss: 5.9846e-04
# Epoch 74/300
# 22/26 [========================>.....] - ETA: 0s - loss: 0.0036
# Epoch 74: val_loss did not improve from 0.00020
# 26/26 [==============================] - 0s 15ms/step - loss: 0.0034 - val_loss: 6.9468e-04
# Epoch 75/300
# 22/26 [========================>.....] - ETA: 0s - loss: 0.0027
# Epoch 75: val_loss did not improve from 0.00020
# 26/26 [==============================] - 0s 14ms/step - loss: 0.0025 - val_loss: 3.6910e-04
# Epoch 76/300
# 24/26 [==========================>...] - ETA: 0s - loss: 0.0029
# Epoch 76: val_loss did not improve from 0.00020
# 26/26 [==============================] - 0s 13ms/step - loss: 0.0027 - val_loss: 4.4073e-04
# Epoch 77/300
# 24/26 [==========================>...] - ETA: 0s - loss: 0.0024
# Epoch 77: val_loss did not improve from 0.00020
# 26/26 [==============================] - 0s 13ms/step - loss: 0.0023 - val_loss: 4.5249e-04
# Epoch 78/300
# 22/26 [========================>.....] - ETA: 0s - loss: 0.0023
# Epoch 78: val_loss did not improve from 0.00020
# 26/26 [==============================] - 0s 14ms/step - loss: 0.0021 - val_loss: 2.5389e-04
# Epoch 79/300
# 25/26 [===========================>..] - ETA: 0s - loss: 0.0025
# Epoch 79: val_loss did not improve from 0.00020
# 26/26 [==============================] - 0s 13ms/step - loss: 0.0025 - val_loss: 6.1894e-04
# Epoch 80/300
# 21/26 [=======================>......] - ETA: 0s - loss: 0.0031
# Epoch 80: val_loss did not improve from 0.00020
# 26/26 [==============================] - 0s 15ms/step - loss: 0.0030 - val_loss: 2.6532e-04
# Epoch 81/300
# 24/26 [==========================>...] - ETA: 0s - loss: 0.0027
# Epoch 81: val_loss did not improve from 0.00020
# 26/26 [==============================] - 0s 13ms/step - loss: 0.0026 - val_loss: 4.0453e-04
# Epoch 82/300
# 25/26 [===========================>..] - ETA: 0s - loss: 0.0028
# Epoch 82: val_loss did not improve from 0.00020
# 26/26 [==============================] - 0s 12ms/step - loss: 0.0028 - val_loss: 5.0889e-04
# Epoch 83/300
# 23/26 [=========================>....] - ETA: 0s - loss: 0.0026
# Epoch 83: val_loss did not improve from 0.00020
# 26/26 [==============================] - 0s 13ms/step - loss: 0.0024 - val_loss: 2.3889e-04
# Epoch 84/300
# 25/26 [===========================>..] - ETA: 0s - loss: 0.0020
# Epoch 84: val_loss did not improve from 0.00020
# 26/26 [==============================] - 0s 12ms/step - loss: 0.0020 - val_loss: 3.2409e-04
# Epoch 85/300
# 25/26 [===========================>..] - ETA: 0s - loss: 0.0021
# Epoch 85: val_loss did not improve from 0.00020
# 26/26 [==============================] - 0s 12ms/step - loss: 0.0020 - val_loss: 2.4756e-04
# Epoch 86/300
# 25/26 [===========================>..] - ETA: 0s - loss: 0.0027
# Epoch 86: val_loss did not improve from 0.00020
# 26/26 [==============================] - 0s 12ms/step - loss: 0.0027 - val_loss: 7.3658e-04
# Epoch 87/300
# 25/26 [===========================>..] - ETA: 0s - loss: 0.0030
# Epoch 87: val_loss did not improve from 0.00020
# 26/26 [==============================] - 0s 12ms/step - loss: 0.0030 - val_loss: 5.2635e-04
# Epoch 88/300
# 22/26 [========================>.....] - ETA: 0s - loss: 0.0022
# Epoch 88: val_loss did not improve from 0.00020
# 26/26 [==============================] - 0s 14ms/step - loss: 0.0020 - val_loss: 2.9776e-04
# Epoch 89/300
# 25/26 [===========================>..] - ETA: 0s - loss: 0.0024
# Epoch 89: val_loss did not improve from 0.00020
# 26/26 [==============================] - 0s 12ms/step - loss: 0.0024 - val_loss: 2.7680e-04
# Epoch 90/300
# 23/26 [=========================>....] - ETA: 0s - loss: 0.0030
# Epoch 90: val_loss did not improve from 0.00020
# 26/26 [==============================] - 0s 14ms/step - loss: 0.0029 - val_loss: 5.9688e-04

# %%
from tensorflow.keras.models import load_model

# Load the best model saved during training from the checkpoint file
# This model was saved using the ModelCheckpoint callback during training
model_from_saved_checkpoint = load_model(checkpoint_path)  # Using the variable defined earlier

# Plot the training and validation loss
# The 'loss' and 'val_loss' values are stored in the 'history' object returned by the 'fit' method
plt.figure(figsize=(16, 7))
plt.plot(history.history['loss'], label='train')
plt.plot(history.history['val_loss'], label='test')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training and Validation Loss Over Epochs')
plt.legend()
plt.show()

# %%
# Making predictions on the test data using the trained model
predicted_lit_price_test_data = model.predict(testX_reshaped)

# Inverse transforming the predictions to bring them back to the original scale
# Using the scaler object that was defined and fit earlier on the training data
predicted_lit_price_test_data = scaler.inverse_transform(predicted_lit_price_test_data)

# Inverse transforming the actual target values of the test data to the original scale
# The testY variable is reshaped to match the required shape for inverse transformation
test_actual = scaler.inverse_transform(testY.reshape(-1, 1))
# Out:
# 16/16 [==============================] - 1s 4ms/step

# %%
# Extracting the corresponding dates for the test data
test_dates = lit_closing_price_groupby_date.index[-len(test_actual):]

plt.figure(figsize=(16, 7))
# Plotting the predicted Bitcoin closing prices for the test data (in red)
plt.plot(test_dates, predicted_lit_price_test_data, 'r', marker='.', label='Predicted Test')
# Plotting the actual Bitcoin closing prices for the test data
plt.plot(test_dates, test_actual, marker='.', label='Actual Test')
# Adding labels to the x and y axes
plt.xlabel('Time')
plt.ylabel('Price')
# Adding a title to the plot
plt.title('Predicted vs Actual Test Prices')
# Adding a legend to the plot to identify the lines
plt.legend()
# Rotating the x-tick labels for better visibility
plt.xticks(rotation=45)
# Displaying the plot
plt.show()

# %%
from keras.models import load_model

# Load the best saved model from the checkpoint file
best_model_path = 'my_best_model.hdf5'
model_from_saved_checkpoint = load_model(best_model_path)

# Making predictions on the training data using the best saved model
predicted_lit_price_train_data = model_from_saved_checkpoint.predict(trainX_reshaped)

# Inverse transforming the predictions using the scaler
predicted_lit_price_train_data = scaler.inverse_transform(predicted_lit_price_train_data)

# Inverse transforming the actual target values of the training data using the scaler
train_actual = scaler.inverse_transform(trainY.reshape(-1, 1))
# Out:
# 26/26 [==============================] - 1s 4ms/step

# %%
plt.figure(figsize=(16, 7))
# Plotting the predicted Bitcoin closing prices for the training data (in red)
plt.plot(predicted_lit_price_train_data, 'r', marker='.', label='Predicted Train')
# Plotting the actual Bitcoin closing prices for the training data
plt.plot(train_actual, marker='.', label='Actual Train')
# Adding labels to the x and y axes
plt.xlabel('Time')
plt.ylabel('Price')
# Adding a title to the plot
plt.title('Predicted vs Actual Train Prices')
# Adding a legend to the plot to identify the lines
plt.legend()
# Displaying the plot
plt.show()

# %%
# Calculating RMSE for test data
rmse_lstm_test = math.sqrt(mean_squared_error(test_actual, predicted_lit_price_test_data))
print('Test RMSE: %.3f' % rmse_lstm_test)

# Calculating RMSE for training data
rmse_lstm_train = math.sqrt(mean_squared_error(train_actual, predicted_lit_price_train_data))
print('Train RMSE: %.3f' % rmse_lstm_train)
# Out:
# Test RMSE: 5.086
# Train RMSE: 13.594

# %%
from sklearn.metrics import mean_absolute_error

# Calculating MAE for training data
# Using actual and predicted values for the training data
mae_train = mean_absolute_error(train_actual, predicted_lit_price_train_data)
# Calculating MAE for test data
# Using actual and predicted values for the test data
mae_test = mean_absolute_error(test_actual, predicted_lit_price_test_data)

# Printing the results
print("Train MAE:", mae_train)
print("Test MAE:", mae_test)
# Out:
# Train MAE: 9.09191933152098
# Test MAE: 3.746614993348414

# %%
def mean_absolute_percentage_error(y_true, y_pred):
    y_true, y_pred = np.array(y_true), np.array(y_pred)
    # Calculating the absolute percentage error for each data point
    # Then taking the mean to get the MAPE
    return np.mean(np.abs((y_true - y_pred) / y_true)) * 100

# Calculating MAPE for training data using actual and predicted values
mape_train = mean_absolute_percentage_error(train_actual, predicted_lit_price_train_data)
# Calculating MAPE for test data using actual and predicted values
mape_test = mean_absolute_percentage_error(test_actual, predicted_lit_price_test_data)

# Printing the results
print("Train MAPE:", mape_train, "%")
print("Test MAPE:", mape_test, "%")
# Out:
# Train MAPE: 7.530882657506764 %
# Test MAPE: 5.232500926912108 %

# %%
from sklearn.metrics import r2_score

# Calculating R² score for training data using actual and predicted values
r2_train = r2_score(train_actual, predicted_lit_price_train_data)
# Calculating R² score for test data using actual and predicted values
r2_test = r2_score(test_actual, predicted_lit_price_test_data)

# Printing the results
print("Train R²:", r2_train)
print("Test R²:", r2_test)
# Out:
# Train R²: 0.9627767059645473
# Test R²: 0.9194907358749881

# %%
testX
testX.shape
# Out:
# (490, 10)

# %%
look_back = 10  # Based on your context, this is the number of previous days you've used to make predictions

# The last 'look_back' days from testX for future predictions
testX_last_days = testX[-look_back:]

print(testX_last_days.shape)
# Out:
# (10, 10)

# %%
testX_last_days
# Out:
# array([[0.17222922, 0.17284876, 0.17754557, 0.17191902, 0.17531503,
#         0.16376744, 0.16483049, 0.16789648, 0.16753741, 0.17045372],
#        [0.17284876, 0.17754557, 0.17191902, 0.17531503, 0.16376744,
#         0.16483049, 0.16789648, 0.16753741, 0.17045372, 0.17908198],
#        [0.17754557, 0.17191902, 0.17531503, 0.16376744, 0.16483049,
#         0.16789648, 0.16753741, 0.17045372, 0.17908198, 0.17765581],
#        [0.17191902, 0.17531503, 0.16376744, 0.16483049, 0.16789648,
#         0.16753741, 0.17045372, 0.17908198, 0.17765581, 0.172458  ],
#        [0.17531503, 0.16376744, 0.16483049, 0.16789648, 0.16753741,
#         0.17045372, 0.17908198, 0.17765581, 0.172458  , 0.17689452],
#        [0.16376744, 0.16483049, 0.16789648, 0.16753741, 0.17045372,
#         0.17908198, 0.17765581, 0.172458  , 0.17689452, 0.15908583],
#        [0.16483049, 0.16789648, 0.16753741, 0.17045372, 0.17908198,
#         0.17765581, 0.172458  , 0.17689452, 0.15908583, 0.14563717],
#        [0.16789648, 0.16753741, 0.17045372, 0.17908198, 0.17765581,
#         0.172458  , 0.17689452, 0.15908583, 0.14563717, 0.14386826],
#        [0.16753741, 0.17045372, 0.17908198, 0.17765581, 0.172458  ,
#         0.17689452, 0.15908583, 0.14563717, 0.14386826, 0.14675608],
#        [0.17045372, 0.17908198, 0.17765581, 0.172458  , 0.17689452,
#         0.15908583, 0.14563717, 0.14386826, 0.14675608, 0.1449731 ]])

# %%
# Number of future days to forecast
forecast_days = 30

# Get the last 'look_back' days from the testX (reshaped) data
testX_last_days = testX_reshaped[-1]

# Ensure the shape is correct for making predictions
testX_last_days_reshaped = testX_last_days.reshape((1, look_back, 1))

# Predicting the next 'forecast_days' values using the model
predicted_forecast_price = []
for i in range(forecast_days):
    predicted_price = model_from_saved_checkpoint.predict(testX_last_days_reshaped)
    predicted_price = scaler.inverse_transform(predicted_price.reshape(-1, 1))
    predicted_forecast_price.append(predicted_price)
    
    # Update testX_last_days_reshaped by removing the oldest value and appending the predicted value
    testX_last_days_reshaped = np.append(testX_last_days_reshaped[:, 1:, :], predicted_price.reshape(1, 1, 1), axis=1)

print("Forecast for the next", forecast_days, "days beyond the actual trading days:", np.array(predicted_forecast_price))
# Out:
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 28ms/step
# Forecast for the next 30 days beyond the actual trading days: [[[  85.880615]]
#
#  [[1621.4075  ]]
#
#  [[1876.0782  ]]
#
#  [[2023.7555  ]]
#
#  [[1406.2773  ]]
#
#  [[ 102.37929 ]]
#
#  [[  60.478603]]
#
#  [[  69.57129 ]]
#
#  [[  60.478603]]
#
#  [[  69.57129 ]]
#
#  [[  60.478603]]
#
#  [[  60.478603]]
#
#  [[  60.478603]]
#
#  [[  60.478603]]
#
#  [[  60.478603]]
#
#  [[  61.74855 ]]
#
#  [[  60.775707]]
#
#  [[  60.852993]]
#
#  [[  60.754616]]
#
#  [[  60.75155 ]]
#
#  [[  60.715588]]
#
#  [[  60.72086 ]]
#
#  [[  60.72821 ]]
#
#  [[  60.73445 ]]
#
#  [[  60.726738]]
#
#  [[  60.728287]]
#
#  [[  60.72522 ]]
#
#  [[  60.725002]]
#
#  [[  60.7245  ]]
#
#  [[  60.724583]]]

# %%
from datetime import timedelta

# Determine the current price by taking the last available closing price
current_price = lit_closing_price_groupby_date.iloc[-1]

# Convert the predicted forecast to a 2D array
predicted_forecast_2d = np.array(predicted_forecast_price).reshape(-1, 1)

# Create a Pandas DataFrame with the 2D array
forecast_df = pd.DataFrame(predicted_forecast_2d, columns=['Predicted_Price'])

# Calculate Loss/Profit based on the predicted price and current price
forecast_df['Loss_Profit'] = forecast_df['Predicted_Price'] - current_price

# Add the current price column
forecast_df['Current_Price'] = current_price

# Add other columns if needed
forecast_df['Coin_Name'] = 'LTC'

# Determine the last available date
last_date = lit_closing_price_groupby_date.index[-1]

# Create future dates for the forecast
forecast_dates = [last_date + timedelta(days=i) for i in range(1, forecast_days + 1)]

# Add future dates to the DataFrame
forecast_df['Date'] = forecast_dates

# Save the DataFrame to a CSV file
forecast_df.to_csv('LIT_forecast.csv', index=False)
